# %% [markdown]
# # 3D Reconstruction of points with History
# ##### Authors: Brett Nelson and Harnoor Dhingra (NSDS Lab, LBNL)

# %%
import pandas as pd
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt 
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation
from sys import exit

# %%
input_handle = pd.read_csv('S3_9/Handle.csv', names=["X", "Y", "Z"])
input_bhandle = pd.read_csv('S3_9/B Handle.csv', names=["X", "Y", "Z"])
input_shoulder = pd.read_csv('S3_9/Shoulder 1.csv', names=["X", "Y", "Z"])
input_forearm = pd.read_csv('S3_9/Forearm 1.csv', names=["X", "Y", "Z"])
input_palm = pd.read_csv('S3_9/Palm 1.csv', names=["X", "Y", "Z"])

# %%
x, y, z = input_handle["X"], input_handle["Y"], input_handle["Z"]
handle_h = np.vstack((x, y, z))
data_handle = [handle_h]

# %%
x, y, z = input_bhandle["X"], input_bhandle["Y"], input_bhandle["Z"]
bhandle_h = np.vstack((x, y, z))
data_bhandle = [bhandle_h]

# %%
x, y, z = input_shoulder["X"], input_shoulder["Y"], input_shoulder["Z"]
shoulder_h = np.vstack((x, y, z))
data_shoulder = [shoulder_h]

# %%
x, y, z = input_forearm["X"], input_forearm["Y"], input_forearm["Z"]
forearm_h = np.vstack((x, y, z))
data_forearm = [forearm_h]

# %%
x, y, z = input_palm["X"], input_palm["Y"], input_palm["Z"]
palm_h = np.vstack((x, y, z))
data_palm = [palm_h]

# %%
input_palm1 = input_palm[0:82]
input_palm2 = input_palm[1:83]
input_palm3 = input_palm[2:84]
input_palm4 = input_palm[3:85]
input_palm5 = input_palm[4:86]

# %%
input_palm1 = input_palm1.reset_index(drop=True)
input_palm2 = input_palm2.reset_index(drop=True)
input_palm3 = input_palm3.reset_index(drop=True)
input_palm4 = input_palm4.reset_index(drop=True)
input_palm5 = input_palm5.reset_index(drop=True)

# %%
x, y, z = input_palm1["X"], input_palm1["Y"], input_palm1["Z"]
palm_h = np.vstack((x, y, z))
data_palm1 = [palm_h]

# %%
x, y, z = input_palm2["X"], input_palm2["Y"], input_palm2["Z"]
palm_h = np.vstack((x, y, z))
data_palm2 = [palm_h]

# %%
x, y, z = input_palm3["X"], input_palm3["Y"], input_palm3["Z"]
palm_h = np.vstack((x, y, z))
data_palm3 = [palm_h]

# %%
x, y, z = input_palm4["X"], input_palm4["Y"], input_palm4["Z"]
palm_h = np.vstack((x, y, z))
data_palm4 = [palm_h]

# %%
x, y, z = input_palm5["X"], input_palm5["Y"], input_palm5["Z"]
palm_h = np.vstack((x, y, z))
data_palm5 = [palm_h]

# %%
def update_lines(num, dataLines, lines) :
    for line, data in zip(lines, dataLines) :
        line.set_data(data[0:2, num-1:num])
        line.set_3d_properties(data[2,num-1:num])
    return lines

# %%
# %matplotlib notebook
fig = plt.figure()
ax = p3.Axes3D(fig)
ax.set_facecolor('black')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_xlabel('X', color ='white')
ax.set_ylabel('Y', color ='white')
ax.set_zlabel('Z', color ='white')
ax.set_title('3D Reconstruction with history', color ='white')
# Out:
# Text(0.5, 0.92, '3D Reconstruction with history')

# %%
# ax.set_xlim3d([-0.012, 0.013])
# ax.set_ylim3d([0.022, 0.024])
# ax.set_zlim3d([0.02, 0.03])

# %%
ax.set_xlim3d([-0.05, 0.05])
ax.set_ylim3d([-0.05, 0.05])
ax.set_zlim3d([-0.05, 0.05])
# Out:
# (-0.05, 0.05)

# %%
lines_palm1 = [ax.plot(data_palm[0][0,0:1], data_palm1[0][1,0:1], data_palm[0][2,0:1], 'o', label = 'At n-4', color = 'azure')[0]]
lines_palm2 = [ax.plot(data_palm[0][0,0:1], data_palm2[0][1,0:1], data_palm[0][2,0:1], 'o', label = 'At n-3', color = 'lightcyan')[0]]
lines_palm3 = [ax.plot(data_palm[0][0,0:1], data_palm3[0][1,0:1], data_palm[0][2,0:1], 'o', label = 'At n-2', color = 'paleturquoise' )[0]]
lines_palm4 = [ax.plot(data_palm[0][0,0:1], data_palm4[0][1,0:1], data_palm[0][2,0:1], 'o', label = 'At n-1', color = 'cyan')[0]]
lines_palm5 = [ax.plot(data_palm[0][0,0:1], data_palm5[0][1,0:1], data_palm[0][2,0:1], 'o', label = 'At n', color = 'blue')[0]]
leg = ax.legend();

# %%
ani1 = animation.FuncAnimation(fig, update_lines, 83, fargs=(data_palm1, lines_palm1),interval=800, blit=False)
ani2 = animation.FuncAnimation(fig, update_lines, 83, fargs=(data_palm2, lines_palm2),interval=800, blit=False)
ani3 = animation.FuncAnimation(fig, update_lines, 83, fargs=(data_palm3, lines_palm3),interval=800, blit=False)
ani4 = animation.FuncAnimation(fig, update_lines, 83, fargs=(data_palm4, lines_palm4),interval=800, blit=False)
ani5 = animation.FuncAnimation(fig, update_lines, 83, fargs=(data_palm5, lines_palm5),interval=800, blit=False)
plt.show()

# %%
# lines_handle = [ax.plot(data_handle[0][0,0:86], data_handle[0][1,0:86], data_handle[0][2,0:86], '*', label = 'Handle')[0]]
# lines_bhandle = [ax.plot(data_bhandle[0][0,0:86], data_bhandle[0][1,0:86], data_bhandle[0][2,0:86], '*', label = 'B Handle')[0]]
# #lines_shoulder = [ax.plot(data_shoulder[0][0,0:86], data_shoulder[0][1,0:86], data_shoulder[0][2,0:86], '*', label = 'Shoulder')[0]]
# #lines_forearm = [ax.plot(data_forearm[0][0,0:86], data_forearm[0][1,0:86], data_forearm[0][2,0:86], '*', label = 'Forearm')[0]]
# lines_palm = [ax.plot(data_palm[0][0,0:86], data_palm[0][1,0:86], data_palm[0][2,0:86], '*', label = 'Palm')[0]]
# leg = ax.legend();

# %%
# ani1 = animation.FuncAnimation(fig, update_lines, 85, fargs=(data_handle, lines_handle),interval=400, blit=False)
# ani2 = animation.FuncAnimation(fig, update_lines, 85, fargs=(data_bhandle, lines_bhandle),interval=400, blit=False)
# #ani3 = animation.FuncAnimation(fig, update_lines, 85, fargs=(data_shoulder, lines_shoulder),interval=400, blit=False)
# #ani4 = animation.FuncAnimation(fig, update_lines, 85, fargs=(data_forearm, lines_forearm),interval=400, blit=False)
# ani5 = animation.FuncAnimation(fig, update_lines, 85, fargs=(data_palm, lines_palm),interval=400, blit=False)

# plt.show()

# %%
# def history(num):
#     input_palm_hist = input_palm[num-4:num+1]
#     input_palm_hist = input_palm_hist.reset_index(drop=True)
#     x, y, z = input_palm_hist["X"], input_palm_hist["Y"], input_palm_hist["Z"]
#     palm_h = np.vstack((x, y, z))
#     data_palm_hist = [palm_h]
#     lines_palm_hist = [ax.plot(data_palm_hist[0][0,0:5], data_palm_hist[0][1,0:5], data_palm_hist[0][2,0:5], '*', label = 'Palm')[0]]
#     ani = animation.FuncAnimation(fig, update_lines, 6, fargs=(data_palm_hist, lines_palm_hist),interval=400, blit=False)
#     plt.show()

# %%
# num = 10 #enter the datapoint number

# history(num)
# input_palm_hist = input_palm[num-4:num+1]
# input_palm_hist = input_palm_hist.reset_index(drop=True)
# x, y, z = input_palm_hist["X"], input_palm_hist["Y"], input_palm_hist["Z"]
# palm_h = np.vstack((x, y, z))
# data_palm_hist = [palm_h]
# lines_palm_hist = [ax.plot(data_palm_hist[0][0,0:5], data_palm_hist[0][1,0:5], data_palm_hist[0][2,0:5], '*', label = 'Palm')[0]]
# ani = animation.FuncAnimation(fig, update_lines, 6, fargs=(data_palm_hist, lines_palm_hist),interval=400, blit=False)
# plt.show()
