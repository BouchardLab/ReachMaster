# %%
import ruptures as rpt
import h5py
import numpy as np
from sklearn.decomposition import SparsePCA
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pdb
# %matplotlib qt
with h5py.File('RM16_920_S3.h5', 'r') as hf:
    blist = list(hf['labels'])
    arms = (hf['timeseries']).value


transformer = SparsePCA(n_components=3, random_state=0)

# first pass, the n_comps dies out around 7-8
# I need to plot some real values against these segmentations, and then limit the # of segments 





for ii in range(0,(arms.shape[0]-45)):
    cxs_kin = arms[ii,:,:,:].reshape(arms.shape[3],arms.shape[2]*arms.shape[1]) # Only predicting on X values ( Can we decimate at /2 sample?)
    #cxs_kin = transformer.fit_transform(arms[ii,:,:,:].reshape(arms.shape[3],arms.shape[1]*arms.shape[2]))
    algo = rpt.Binseg(model='ar').fit(cxs_kin)
    #algo = rpt.Window(width=30, model="ar").fit(cxs_kin)
    #algo = rpt.Pelt(model="rbf").fit(cxs_kin)
    result = algo.predict(blist[ii][4]+1)
    #result = algo.predict(pen=4)
    #rpt.display(cxs_kin,np.linspace(0,blist[ii][4]), result)
    #plt.show()
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #pdb.set_trace()
    ax.plot(np.linspace(0,900,900),arms[ii,0,2,:],color='r',label='XPos Left Palm')
    ax.plot(np.linspace(0,900,900),arms[ii,1,2,:],color='b',label='YPos Left Palm')
    ax.plot(np.linspace(0,900,900),arms[ii,0,11,:],color='g',label='XPos Right Palm')
    ax.plot(np.linspace(0,900,900),arms[ii,1,11,:],color='y',label='YPos Right Palm')
    #pdb.set_trace()
    ax.vlines(result,0,2,color='k',label='rupture splits on PCS')
    plt.legend()
    plt.show()
# Out:
# C:\Users\bassp\anaconda3\envs\DLC-GPU\lib\site-packages\ipykernel_launcher.py:12: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   if sys.path[0] == '':

# %%
def slice video
# Out:
# [30, 36]

# %%
def calc_3v_features(array_ts):
    pdb.set_trace()
    l_arm = array_ts[:,:,1:4,:].reshape(array_ts.shape[0],array_ts.shape[1]*3,array_ts[3])
    r_arm = array_ts[:,:,-5:-1,:].reshape(array_ts.shape[0],array_ts.shape[1]*4,array_ts[3])
    l_arm_cp = np.mean(np.diff(l_arm,axis=2),axis=1)# get total mean change of arm frame by frame
    r_arm_cp = np.mean(np.diff(r_arm,axis=2),axis=1)
    l_palm = array_ts[:,:,2,:]
    r_palm = array_ts[:,:,11,:]
    l_palm_cp = np.mean(np.diff(l_palm,axis=2),axis=1) # get mean of frame-by-frame velocities (not real-world velocities)
    r_palm_cp = np.mean(np.diff(r_palm,axis=2),axis=1) 
    
    return l_arm_cp,r_arm_cp,l_palm_cp,r_palm_cp


def find_changepoints(arm_cp_array, pred_seg=False):
    # Find where values change per trial
    segments = []
    for i in range(0,arm_cp_array.shape[0]):
        pdb.set_trace()
    return segments


l_arm_cp,r_arm_cp,l_palm_cp,r_palm_cp = calc_3v_features(arms)
# Out:
# > <ipython-input-36-19c49befc24d>(3)calc_3v_features()
#       1 def calc_3v_features(array_ts):
#       2     pdb.set_trace()
# ----> 3     l_arm = array_ts[:,:,1:4,:].reshape(array_ts.shape[0],array_ts.shape[1]*3,array_ts[3])
#       4     r_arm = array_ts[:,:,-5:-1,:].reshape(array_ts.shape[0],array_ts.shape[1]*4,array_ts[3])
#           -4.05039445e-03, -4.05039445e-03, -4.09946178e-03],
#          [ 1.44419637e-02,  1.44344335e-02,  1.44284444e-02, ...,
#           -1.47800451e-03, -1.35599856e-03, -1.23539488e-03]],
#
#         [[ 4.04158986e-03,  1.52380648e-03,  1.52380648e-03, ...,
#            1.21483680e-03,  1.21483680e-03,  1.21483680e-03],
#          [ 2.25394225e-02,  2.26104559e-02,  2.26656786e-02, ...,
#            2.55062104e-03,  2.04827191e-03,  1.94204852e-03],
#          [ 1.91042771e-02,  1.91042771e-02,  1.83040573e-02, ...,
#           -6.57791539e-03, -6.57791539e-03, -6.58758013e-03]]],
#
#
#        [[[ 7.29780133e-03,  6.86156686e-03,  6.51234782e-03, ...,
#            2.77652266e-03,  2.83280956e-03,  4.75170113e-03],
#          [ 2.30698871e-02,  2.30698871e-02,  2.30649411e-02, ...,
#           -3.38003552e-03, -3.38003552e-03, -3.38003552e-03],
#          [ 2.33432710e-02,  2.33432710e-02,  2.33432710e-02, ...,
#           -4.68988518e-03, -1.07937771e-02, -1.08330176e-02]],
#
#         [[-7.72417779e-03, -8.21828733e-03, -9.29083739e-03, ...,
#           -1.24747853e-02, -1.24747853e-02, -1.24747853e-02],
#          [ 1.71838654e-02,  1.68641600e-02,  1.56859352e-02, ...,
#           -2.66706411e-02, -2.68107357e-02, -2.68107357e-02],
#          [ 2.69477085e-03,  5.63360175e-03,  6.18277487e-03, ...,
#           -1.79063030e-02, -1.79387603e-02, -1.80604187e-02]],
#
#         [[ 2.22222733e-02,  2.21732245e-02,  2.21732245e-02, ...,
#           -1.30901756e-02, -1.30901756e-02, -1.30575843e-02],
#          [ 2.25719822e-02,  2.24444928e-02,  2.24444928e-02, ...,
#           -5.47881719e-03, -5.25336660e-03, -5.23222597e-03],
#          [ 2.51839768e-02,  2.51808014e-02,  2.51740959e-02, ...,
#           -1.04219403e-02, -1.04369594e-02, -1.04405734e-02]]]])
# ipdb> exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-36-19c49befc24d> in <module>
#      21
#      22
# ---> 23 l_arm_cp,r_arm_cp,l_palm_cp,r_palm_cp = calc_3v_features(arms)
#
# <ipython-input-36-19c49befc24d> in calc_3v_features(array_ts)
#       1 def calc_3v_features(array_ts):
#       2     pdb.set_trace()
# ----> 3     l_arm = array_ts[:,:,1:4,:].reshape(array_ts.shape[0],array_ts.shape[1]*3,array_ts[3])
#       4     r_arm = array_ts[:,:,-5:-1,:].reshape(array_ts.shape[0],array_ts.shape[1]*4,array_ts[3])
#       5     l_arm_cp = np.mean(np.diff(l_arm,axis=2),axis=1)# get total mean change of arm frame by frame
#
# <ipython-input-36-19c49befc24d> in calc_3v_features(array_ts)
#       1 def calc_3v_features(array_ts):
#       2     pdb.set_trace()
# ----> 3     l_arm = array_ts[:,:,1:4,:].reshape(array_ts.shape[0],array_ts.shape[1]*3,array_ts[3])
#       4     r_arm = array_ts[:,:,-5:-1,:].reshape(array_ts.shape[0],array_ts.shape[1]*4,array_ts[3])
#       5     l_arm_cp = np.mean(np.diff(l_arm,axis=2),axis=1)# get total mean change of arm frame by frame
#
# ~\anaconda3\envs\DLC-GPU\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# ~\anaconda3\envs\DLC-GPU\lib\bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:
